# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Titanic Dataset.csv')
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.values
# Out:
# array([[1, 0, 3, ..., 7.25, nan, 'S'],
#        [2, 1, 1, ..., 71.2833, 'C85', 'C'],
#        [3, 1, 3, ..., 7.925, nan, 'S'],
#        ...,
#        [889, 0, 3, ..., 23.45, nan, 'S'],
#        [890, 1, 1, ..., 30.0, 'C148', 'C'],
#        [891, 0, 3, ..., 7.75, nan, 'Q']], dtype=object)

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.drop(['Cabin'],axis = 1,inplace = True)

# %%
df.isna
# Out:
# <bound method DataFrame.isna of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.fillna(np.mean).isna()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False  False  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Embarked
# ...

# %%
df.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.fillna(np.mean).isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df.value_counts()
# Out:
# PassengerId  Survived  Pclass  Name                                             Sex     Age    SibSp  Parch  Ticket       Fare      Embarked
# 1            0         3       Braund, Mr. Owen Harris                          male    22.00  1      0      A/5 21171    7.2500    S           1
# 622          1         1       Kimball, Mr. Edwin Nelson Jr                     male    42.00  1      0      11753        52.5542   S           1
# 595          0         2       Chapman, Mr. John Henry                          male    37.00  1      0      SC/AH 29037  26.0000   S           1
# 596          0         3       Van Impe, Mr. Jean Baptiste                      male    36.00  1      1      345773       24.1500   S           1
# 598          0         3       Johnson, Mr. Alfred                              male    49.00  0      0      LINE         0.0000    S           1
# ...

# %%
df.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Embarked       889
# dtype: int64

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df['Age'].value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: Age, Length: 88, dtype: int64

# %%
df['Parch'].value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %%
dir(df)
# Out:
# ['Age',
#  'Cabin',
#  'Embarked',
#  'Fare',
#  'Name',
#  'Parch',
#  'PassengerId',
#  'Pclass',
#  'Sex',
#  'SibSp',
#  'Survived',
#  'T',
#  'Ticket',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
# ...

# %%
df['Survived'].value_counts().plot(kind = "pie");

# %%
import seaborn as sns
sns.barplot(data = df, x = df["Survived"],y = df["Survived"].value_counts(), hue = df['Sex']);

# %%
df['Survived'].value_counts().plot(kind = "pie");

# %%
sns.displot(data = df,x = df['Sex']);

# %%
sns.displot(data = df,x = df['Age']);

# %%
import seaborn as sns
sns.barplot(data = df, x = df["Survived"],y = df["Survived"].value_counts(), hue = df['Age']);

# %%
sns.displot(data = df, x = df["Age"], hue = df['Pclass']);

# %%
sns.displot(data = df, x = df["Age"], hue = df['Sex']);

# %%
sns.heatmap(df.corr());

# %%
sns.heatmap(df.corr(),annot = True);

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
sns.scatterplot(data = df, x = df["Age"], hue = df['Sex']);

# %%
df[["Age"]].replace(22,"A")
# Out:
#       Age
# 0       A
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# ..    ...
# 886  27.0
# 887  19.0
# 888   NaN
# 889  26.0
# 890  32.0
#
# [891 rows x 1 columns]

# %%
def sort_age(col):
    if col < 18:
        col.replace("Child")
    return col

# %%
(df["Age"] < 18).sum()
# Out:
# 113

# %%
df[df["Age"] < 18]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 9             10         1       2      Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3          Sandstrom, Miss. Marguerite Rut
# 14            15         0       3     Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0       3                     Rice, Master. Eugene
# ..           ...       ...     ...                                      ...
# 850          851         0       3  Andersson, Master. Sigvard Harald Elias
# 852          853         0       3                  Boulos, Miss. Nourelain
# 853          854         1       1                Lines, Miss. Mary Conover
# 869          870         1       3          Johnson, Master. Harold Theodor
# 875          876         1       3         Najib, Miss. Adele Kiamie "Jane"
#
# ...

# %%
df[df["Age"] < 18].replace("Child", inplace = True)

# %%
df[df["Age"] < 18]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 9             10         1       2      Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3          Sandstrom, Miss. Marguerite Rut
# 14            15         0       3     Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0       3                     Rice, Master. Eugene
# ..           ...       ...     ...                                      ...
# 850          851         0       3  Andersson, Master. Sigvard Harald Elias
# 852          853         0       3                  Boulos, Miss. Nourelain
# 853          854         1       1                Lines, Miss. Mary Conover
# 869          870         1       3          Johnson, Master. Harold Theodor
# 875          876         1       3         Najib, Miss. Adele Kiamie "Jane"
#
# ...

# %%
sns.scatterplot(data = df, x = "Survived", y = "Age");

# %%
sns.scatterplot(data = df, x = "Survived", y = "Name");

# %%
sns.scatterplot(data = df, x = "Survived", y = "Sex");

# %%
sns.scatterplot(data = df, x = "Survived", y = "SibSp");

# %%
sns.scatterplot(data = df, x = "Name", y = "Survived");

# %%
sns.scatterplot(data = df, x = "Survived", y = "Sex")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 sns.scatterplot(data = df, x = "Survived", y = "Sex")
#
# NameError: name 'sns' is not defined

# %%
df = pd.read_csv('Titanic Dataset.csv')
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.groupby(df["Survived"])['Sex'].count()
# Out:
# Survived
# 0    549
# 1    342
# Name: Sex, dtype: int64

# %%
a = df.pivot_table(values='PassengerId' , index = 'Survived',columns="Sex",aggfunc='count')

# %%
a
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109

# %%
a.plot(kind='bar');

# %%
df.groupby(by=["Survived","Sex"])["Age"].count()
# Out:
# Survived  Sex
# 0         female     64
#           male      360
# 1         female    197
#           male       93
# Name: Age, dtype: int64

# %%
b = df.pivot_table(values='PassengerId' , index = 'Survived',columns="Pclass",aggfunc='count')
b
# Out:
# Pclass      1   2    3
# Survived
# 0          80  97  372
# 1         136  87  119

# %%
# Out:
# Pclass      1    2    3
# Embarked
# C          85   17   66
# Q           2    3   72
# S         127  164  353

# %%
c = df.pivot_table(values='PassengerId' , index = 'Survived',columns="Embarked",aggfunc='count')
c
# Out:
# Embarked   C   Q    S
# Survived
# 0         75  47  427
# 1         93  30  217

# %%
c.plot(kind='bar');

# %%
d = df.groupby(by=["Survived","Sex"])["Age"].count()
d
# Out:
# Survived  Sex
# 0         female     64
#           male      360
# 1         female    197
#           male       93
# Name: Age, dtype: int64

# %%
d.plot(kind='bar',color = ['r','b','y','pink']);

# %%
a = {"ID":[1,2,3,4],
     "Name":["Yug","Moksh","Chintan","Khushi"],
     "City":["Dharti","Swarg","Pruthvi","Pacific"]}
df = pd.DataFrame(a)
df
# Out:
#    ID     Name  Age     City
# 0   1      Yug   12   Dharti
# 1   2    Moksh   14    Swarg
# 2   3  Chintan   25  Pruthvi
# 3   4   Khushi   22  Pacific

# %%
df["Age"]=[12,25,13,15]
df
# Out:
#    ID     Name  Age     City
# 0   1      Yug   12   Dharti
# 1   2    Moksh   25    Swarg
# 2   3  Chintan   13  Pruthvi
# 3   4   Khushi   15  Pacific

# %%
a = {"ID":[1,2,3,4,5],
     "Name":["Yug","Moksh","Chintan","Khushi","khatri"],
     "Age":[12,25,13,15,35],
     "City":["Dharti","Swarg","Pruthvi","Pacific","Hawa me"],
     "Weight":[25,36,65,78,98]}
df = pd.DataFrame(a)
df
# Out:
#    ID     Name  Age     City  Weight
# 0   1      Yug   12   Dharti      25
# 1   2    Moksh   25    Swarg      36
# 2   3  Chintan   13  Pruthvi      65
# 3   4   Khushi   15  Pacific      78
# 4   5   khatri   35  Hawa me      98

# %%
a = {"ID":[1,2,3,4,5],"Weight":[25,36,65,78,98]}
df1 = pd.DataFrame(a)
df1
# Out:
#    ID  Weight
# 0   1      25
# 1   2      36
# 2   3      65
# 3   4      78
# 4   5      98

# %%
b = {"ID":[1,2,3,4,5],
     "Name":["Yug","Moksh","Chintan","Khushi","khatri"],
     "Age":[12,25,13,15,35],
     "City":["Dharti","Swarg","Pruthvi","Pacific","Hawa me"]}
df2 = pd.DataFrame(b)
df2
# Out:
#    ID     Name  Age     City
# 0   1      Yug   12   Dharti
# 1   2    Moksh   25    Swarg
# 2   3  Chintan   13  Pruthvi
# 3   4   Khushi   15  Pacific
# 4   5   khatri   35  Hawa me

# %%
pd.concat([df2,df1])
# Out:
#    ID     Name   Age     City  Weight
# 0   1      Yug  12.0   Dharti     NaN
# 1   2    Moksh  25.0    Swarg     NaN
# 2   3  Chintan  13.0  Pruthvi     NaN
# 3   4   Khushi  15.0  Pacific     NaN
# 4   5   khatri  35.0  Hawa me     NaN
# 0   1      NaN   NaN      NaN    25.0
# 1   2      NaN   NaN      NaN    36.0
# 2   3      NaN   NaN      NaN    65.0
# 3   4      NaN   NaN      NaN    78.0
# 4   5      NaN   NaN      NaN    98.0

# %%
df1.merge(df2)
# Out:
#    ID  Weight     Name  Age     City
# 0   1      25      Yug   12   Dharti
# 1   2      36    Moksh   25    Swarg
# 2   3      65  Chintan   13  Pruthvi
# 3   4      78   Khushi   15  Pacific
# 4   5      98   khatri   35  Hawa me

# %%
df1.merge(df2,how = "outer")
# Out:
#    ID  Weight     Name  Age     City
# 0   1      25      Yug   12   Dharti
# 1   2      36    Moksh   25    Swarg
# 2   3      65  Chintan   13  Pruthvi
# 3   4      78   Khushi   15  Pacific
# 4   5      98   khatri   35  Hawa me

# %%
df1.merge(df2,how = "right")
# Out:
#    ID  Weight     Name  Age     City
# 0   1      25      Yug   12   Dharti
# 1   2      36    Moksh   25    Swarg
# 2   3      65  Chintan   13  Pruthvi
# 3   4      78   Khushi   15  Pacific
# 4   5      98   khatri   35  Hawa me

# %%
df1.merge(df2,how = "left")
# Out:
#    ID  Weight     Name  Age     City
# 0   1      25      Yug   12   Dharti
# 1   2      36    Moksh   25    Swarg
# 2   3      65  Chintan   13  Pruthvi
# 3   4      78   Khushi   15  Pacific
# 4   5      98   khatri   35  Hawa me

# %%
df1.merge(df2,how = "inner")
# Out:
#    ID  Weight     Name  Age     City
# 0   1      25      Yug   12   Dharti
# 1   2      36    Moksh   25    Swarg
# 2   3      65  Chintan   13  Pruthvi
# 3   4      78   Khushi   15  Pacific
# 4   5      98   khatri   35  Hawa me

# %%
df1.merge(df2,how = "left").sort_index()
# Out:
#    ID  Weight     Name  Age     City
# 0   1      25      Yug   12   Dharti
# 1   2      36    Moksh   25    Swarg
# 2   3      65  Chintan   13  Pruthvi
# 3   4      78   Khushi   15  Pacific
# 4   5      98   khatri   35  Hawa me

# %%
df2.sort_values('Age')
# Out:
#    ID     Name  Age     City
# 0   1      Yug   12   Dharti
# 2   3  Chintan   13  Pruthvi
# 3   4   Khushi   15  Pacific
# 1   2    Moksh   25    Swarg
# 4   5   khatri   35  Hawa me

# %%
a = lambda x:x**2
a(2)
# Out:
# 4

# %%
df1["weight_squre"] = df1['Weight'].apply(lambda x:x**2)
df1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [55], in <cell line: 1>()
# ----> 1 df1["weight_squre"] = df1['Weight'].apply(lambda x:x**2)
#       2 df1
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py:389, in RangeIndex.get_loc(self, key, method, tolerance)
#     387             raise KeyError(key) from err
#     388     self._check_indexing_error(key)
# --> 389     raise KeyError(key)
#     390 return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 'Weight'

# %%
df["Age"].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
new = df.loc[:50]
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df["Fare"].unique()
# Out:
# array([  7.25  ,  71.2833,   7.925 ,  53.1   ,   8.05  ,   8.4583,
#         51.8625,  21.075 ,  11.1333,  30.0708,  16.7   ,  26.55  ,
#         31.275 ,   7.8542,  16.    ,  29.125 ,  13.    ,  18.    ,
#          7.225 ,  26.    ,   8.0292,  35.5   ,  31.3875, 263.    ,
#          7.8792,   7.8958,  27.7208, 146.5208,   7.75  ,  10.5   ,
#         82.1708,  52.    ,   7.2292,  11.2417,   9.475 ,  21.    ,
#         41.5792,  15.5   ,  21.6792,  17.8   ,  39.6875,   7.8   ,
#         76.7292,  61.9792,  27.75  ,  46.9   ,  80.    ,  83.475 ,
#         27.9   ,  15.2458,   8.1583,   8.6625,  73.5   ,  14.4542,
#         56.4958,   7.65  ,  29.    ,  12.475 ,   9.    ,   9.5   ,
#          7.7875,  47.1   ,  15.85  ,  34.375 ,  61.175 ,  20.575 ,
#         34.6542,  63.3583,  23.    ,  77.2875,   8.6542,   7.775 ,
#         24.15  ,   9.825 ,  14.4583, 247.5208,   7.1417,  22.3583,
#          6.975 ,   7.05  ,  14.5   ,  15.0458,  26.2833,   9.2167,
# ...
